# %% [markdown]
# # SQL Interview Questions  - Quiz
#
#
# ## Introduction
#
# This quiz contains questions on topics you can expect to see in an interview pertaining to SQL and Relational Databases. Some of them are multiple choice, while some are short answer. For these short answer questions, double click on the Jupyter Notebook and type your answer below the line.
#
# ## Question 1
#
# What are the 4 main datatypes in SQLite3? Can we use other common types from other kinds of SQL?
#
# Type your answer below this line:
# Numeric datatype, Character , Date and time datatypes, Boolean datatypes.
# Yes we can use other types from other kinds of SQL. ______________________________________________________________________________________________________________________________
#
#
#
#
#
# ## Question 2
#
# Explain the relationship between **Primary Keys** and **Foreign Keys**.
#
# Type your answer below this line:
# Primary key is a unique identifier in a given table. when used as reference in another table it becomes a foreign key.
# _______________________________________________________________________________________________________________________________
#
#
#
#
#
# ## Question 3
#
# Explain the different types of relationships entities can have in a SQL database.
#
# Type your answer below this line:
# one-to-many is a relationship there a record in one table is related to many one or more records in another table and vise versa.
#
# Many-to-many relationship is one in which many records from a table are related to many other records in another table and vise versa. could be two or more.
# _______________________________________________________________________________________________________________________________
#
#
# ## Question 4
#
# Explain the various types of JOINs possible with SQL.
#
# Type your answer below this line:
# inner join combines two or more tables on records that match from all this tables
# left join combines all the records from the first table with matching records from the second table.
# right join combines all records from the right table and matching records from the table on the left.
# outer join combines all records from all the tables.
# _______________________________________________________________________________________________________________________________
#
#
#
# ## Question 5
#
# Explain the relationship between Aggregate functions and GROUP BY statements.
#
# Type your answer below this line:
# group by statements are used with aggregate function to aggregate data that can be used in groups._____________________________________________________________________________________________________________________
#
#
#
# ## Question 6
#
# What role do Associative Entities play (JOIN Tables) in many-to-many JOINs?
#
#
# Type your answer below this line:
# they join tables that have many-to-many relationship. basically it combines entities that have multiple relationships between them.
# ______________________________________________________________________________________________________________________________
#
#
#
# ## Summary
#
# In this lesson, we practiced answering open-ended interview questions for SQL and Relational Databases.
